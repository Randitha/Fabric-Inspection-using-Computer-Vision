# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import ResNet50
from tensorflow.keras import layers, models
from sklearn.metrics import classification_report, accuracy_score, precision_score, recall_score, f1_score

# %%
# Data generators
train_datagen = ImageDataGenerator(rescale=1./255, rotation_range=20, zoom_range=0.2,
                                   width_shift_range=0.2, height_shift_range=0.2, shear_range=0.2, 
                                   horizontal_flip=True, fill_mode='nearest')

valid_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(
    '/Users/randithasenarathne/FYP/FabricDefects/cls-multi/train',
    target_size=(64, 64),
    batch_size=32,
    class_mode='categorical')

valid_generator = valid_datagen.flow_from_directory(
    '/Users/randithasenarathne/FYP/FabricDefects/cls-multi/val',
    target_size=(64, 64),
    batch_size=32,
    class_mode='categorical')
# Out:
# Found 17586 images belonging to 5 classes.
# Found 5024 images belonging to 5 classes.

# %%
# Load the pre-trained ResNet50 model without the top classification layer
base_model = ResNet50(weights='imagenet', include_top=False, input_shape=(64, 64, 3))

# Freeze the base model layers
base_model.trainable = False

# Build the model
model = models.Sequential([
    base_model,
    layers.GlobalAveragePooling2D(),
    layers.Dense(1024, activation='relu'),
    layers.Dropout(0.5),
    layers.Dense(5, activation='softmax')  # 5 classes
])

# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Train the model
history = model.fit(train_generator, epochs=100, validation_data=valid_generator)

# Unfreeze the base model for fine-tuning (optional)
base_model.trainable = True
model.compile(optimizer=tf.keras.optimizers.Adam(1e-5), loss='categorical_crossentropy', metrics=['accuracy'])

# Fine-tune for a few more epochs
history_fine = model.fit(train_generator, epochs=50, validation_data=valid_generator)
# Out:
# Epoch 1/100
# /Applications/anaconda3/lib/python3.11/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 67s 118ms/step - accuracy: 0.2000 - loss: 1.6735 - val_accuracy: 0.1994 - val_loss: 1.6090
# Epoch 2/100
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 67s 122ms/step - accuracy: 0.2042 - loss: 1.6096 - val_accuracy: 0.2022 - val_loss: 1.6094
# Epoch 3/100
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 68s 123ms/step - accuracy: 0.1931 - loss: 1.6097 - val_accuracy: 0.2022 - val_loss: 1.6094
# Epoch 4/100
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 66s 120ms/step - accuracy: 0.1970 - loss: 1.6096 - val_accuracy: 0.2022 - val_loss: 1.6094
# Epoch 5/100
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 63s 115ms/step - accuracy: 0.1989 - loss: 1.6097 - val_accuracy: 0.2022 - val_loss: 1.6094
# Epoch 6/100
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 63s 115ms/step - accuracy: 0.1984 - loss: 1.6096 - val_accuracy: 0.2024 - val_loss: 1.6094
# Epoch 7/100
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 64s 115ms/step - accuracy: 0.2029 - loss: 1.6097 - val_accuracy: 0.2024 - val_loss: 1.6096
# Epoch 8/100
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 64s 116ms/step - accuracy: 0.2039 - loss: 1.6095 - val_accuracy: 0.2024 - val_loss: 1.6094
# Epoch 9/100
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 64s 117ms/step - accuracy: 0.1985 - loss: 1.6098 - val_accuracy: 0.2024 - val_loss: 1.6094
# Epoch 10/100
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 66s 119ms/step - accuracy: 0.2029 - loss: 1.6095 - val_accuracy: 0.2024 - val_loss: 1.6094
# Epoch 11/100
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 65s 117ms/step - accuracy: 0.2006 - loss: 1.6095 - val_accuracy: 0.2012 - val_loss: 1.6094
# Epoch 12/100
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 65s 118ms/step - accuracy: 0.2032 - loss: 1.6095 - val_accuracy: 0.2012 - val_loss: 1.6094
# Epoch 13/100
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 64s 116ms/step - accuracy: 0.2002 - loss: 1.6093 - val_accuracy: 0.2012 - val_loss: 1.6094
# Epoch 14/100
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 64s 116ms/step - accuracy: 0.2044 - loss: 1.6095 - val_accuracy: 0.2024 - val_loss: 1.6094
# Epoch 15/100
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 64s 116ms/step - accuracy: 0.2040 - loss: 1.6098 - val_accuracy: 0.2024 - val_loss: 1.6094
# Epoch 16/100
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 64s 116ms/step - accuracy: 0.2030 - loss: 1.6094 - val_accuracy: 0.1998 - val_loss: 1.6094
# Epoch 17/100
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 64s 116ms/step - accuracy: 0.2022 - loss: 1.6095 - val_accuracy: 0.2024 - val_loss: 1.6094
# Epoch 18/100
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 64s 117ms/step - accuracy: 0.1992 - loss: 1.6095 - val_accuracy: 0.2024 - val_loss: 1.6094
# Epoch 19/100
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 64s 116ms/step - accuracy: 0.2080 - loss: 1.6094 - val_accuracy: 0.2024 - val_loss: 1.6094
# Epoch 20/100
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 68s 124ms/step - accuracy: 0.2033 - loss: 1.6094 - val_accuracy: 0.1998 - val_loss: 1.6094
# Epoch 21/100
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 65s 118ms/step - accuracy: 0.1958 - loss: 1.6096 - val_accuracy: 0.2024 - val_loss: 1.6094
# Epoch 22/100
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 65s 118ms/step - accuracy: 0.2047 - loss: 1.6095 - val_accuracy: 0.2012 - val_loss: 1.6094
# Epoch 23/100
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 65s 119ms/step - accuracy: 0.1956 - loss: 1.6096 - val_accuracy: 0.2024 - val_loss: 1.6094
# Epoch 24/100
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 65s 119ms/step - accuracy: 0.1988 - loss: 1.6095 - val_accuracy: 0.2024 - val_loss: 1.6094
# Epoch 25/100
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 66s 120ms/step - accuracy: 0.2063 - loss: 1.6094 - val_accuracy: 0.2012 - val_loss: 1.6094
# Epoch 26/100
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 65s 118ms/step - accuracy: 0.2027 - loss: 1.6094 - val_accuracy: 0.1998 - val_loss: 1.6094
# Epoch 27/100
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 65s 118ms/step - accuracy: 0.2027 - loss: 1.6094 - val_accuracy: 0.2024 - val_loss: 1.6094
# Epoch 28/100
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 65s 118ms/step - accuracy: 0.2048 - loss: 1.6095 - val_accuracy: 0.2024 - val_loss: 1.6094
# Epoch 29/100
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 65s 118ms/step - accuracy: 0.2055 - loss: 1.6095 - val_accuracy: 0.2012 - val_loss: 1.6094
# Epoch 30/100
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 65s 118ms/step - accuracy: 0.2014 - loss: 1.6095 - val_accuracy: 0.2012 - val_loss: 1.6094
# Epoch 31/100
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 66s 119ms/step - accuracy: 0.1974 - loss: 1.6095 - val_accuracy: 0.2024 - val_loss: 1.6094
# Epoch 32/100
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 66s 120ms/step - accuracy: 0.1965 - loss: 1.6095 - val_accuracy: 0.2024 - val_loss: 1.6094
# Epoch 33/100
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 66s 120ms/step - accuracy: 0.2059 - loss: 1.6095 - val_accuracy: 0.2012 - val_loss: 1.6094
# Epoch 34/100
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 66s 119ms/step - accuracy: 0.1999 - loss: 1.6095 - val_accuracy: 0.2012 - val_loss: 1.6094
# Epoch 35/100
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 66s 119ms/step - accuracy: 0.2004 - loss: 1.6095 - val_accuracy: 0.2024 - val_loss: 1.6094
# Epoch 36/100
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 66s 119ms/step - accuracy: 0.1913 - loss: 1.6096 - val_accuracy: 0.2024 - val_loss: 1.6094
# Epoch 37/100
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 66s 120ms/step - accuracy: 0.1984 - loss: 1.6097 - val_accuracy: 0.2024 - val_loss: 1.6094
# Epoch 38/100
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 66s 120ms/step - accuracy: 0.1979 - loss: 1.6095 - val_accuracy: 0.2024 - val_loss: 1.6094
# Epoch 39/100
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 66s 120ms/step - accuracy: 0.2029 - loss: 1.6096 - val_accuracy: 0.2024 - val_loss: 1.6094
# Epoch 40/100
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 67s 121ms/step - accuracy: 0.1980 - loss: 1.6096 - val_accuracy: 0.2024 - val_loss: 1.6094
# Epoch 41/100
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 66s 120ms/step - accuracy: 0.2065 - loss: 1.6094 - val_accuracy: 0.2024 - val_loss: 1.6094
# Epoch 42/100
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 66s 120ms/step - accuracy: 0.2005 - loss: 1.6095 - val_accuracy: 0.2024 - val_loss: 1.6094
# Epoch 43/100
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 64s 117ms/step - accuracy: 0.2007 - loss: 1.6095 - val_accuracy: 0.2024 - val_loss: 1.6094
# Epoch 44/100
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 66s 120ms/step - accuracy: 0.2018 - loss: 1.6094 - val_accuracy: 0.2024 - val_loss: 1.6094
# Epoch 45/100
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 66s 120ms/step - accuracy: 0.1944 - loss: 1.6096 - val_accuracy: 0.2024 - val_loss: 1.6094
# Epoch 46/100
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 66s 120ms/step - accuracy: 0.2007 - loss: 1.6096 - val_accuracy: 0.2024 - val_loss: 1.6094
# Epoch 47/100
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 66s 119ms/step - accuracy: 0.1961 - loss: 1.6096 - val_accuracy: 0.2024 - val_loss: 1.6094
# Epoch 48/100
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 66s 120ms/step - accuracy: 0.1962 - loss: 1.6096 - val_accuracy: 0.2024 - val_loss: 1.6094
# Epoch 49/100
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 66s 120ms/step - accuracy: 0.2054 - loss: 1.6094 - val_accuracy: 0.2012 - val_loss: 1.6094
# Epoch 50/100
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 68s 123ms/step - accuracy: 0.2021 - loss: 1.6094 - val_accuracy: 0.2012 - val_loss: 1.6094
# Epoch 51/100
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 72s 130ms/step - accuracy: 0.1981 - loss: 1.6095 - val_accuracy: 0.2024 - val_loss: 1.6094
# Epoch 52/100
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 66s 120ms/step - accuracy: 0.2050 - loss: 1.6094 - val_accuracy: 0.2024 - val_loss: 1.6094
# Epoch 53/100
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 66s 119ms/step - accuracy: 0.1953 - loss: 1.6095 - val_accuracy: 0.2012 - val_loss: 1.6094
# Epoch 54/100
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 66s 119ms/step - accuracy: 0.1977 - loss: 1.6096 - val_accuracy: 0.2012 - val_loss: 1.6094
# Epoch 55/100
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 66s 119ms/step - accuracy: 0.1946 - loss: 1.6095 - val_accuracy: 0.2012 - val_loss: 1.6094
# Epoch 56/100
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 66s 120ms/step - accuracy: 0.1919 - loss: 1.6096 - val_accuracy: 0.2024 - val_loss: 1.6094
# Epoch 57/100
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 66s 120ms/step - accuracy: 0.2057 - loss: 1.6093 - val_accuracy: 0.2024 - val_loss: 1.6094
# Epoch 58/100
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 66s 120ms/step - accuracy: 0.1991 - loss: 1.6095 - val_accuracy: 0.2024 - val_loss: 1.6094
# Epoch 59/100
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 67s 121ms/step - accuracy: 0.2024 - loss: 1.6095 - val_accuracy: 0.2024 - val_loss: 1.6094
# Epoch 60/100
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 66s 120ms/step - accuracy: 0.2010 - loss: 1.6095 - val_accuracy: 0.2024 - val_loss: 1.6094
# Epoch 61/100
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 66s 120ms/step - accuracy: 0.1998 - loss: 1.6096 - val_accuracy: 0.2024 - val_loss: 1.6094
# Epoch 62/100
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 66s 120ms/step - accuracy: 0.2040 - loss: 1.6094 - val_accuracy: 0.2024 - val_loss: 1.6094
# Epoch 63/100
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 67s 121ms/step - accuracy: 0.2006 - loss: 1.6095 - val_accuracy: 0.2024 - val_loss: 1.6094
# Epoch 64/100
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 67s 122ms/step - accuracy: 0.1997 - loss: 1.6095 - val_accuracy: 0.2024 - val_loss: 1.6094
# Epoch 65/100
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 66s 120ms/step - accuracy: 0.1969 - loss: 1.6094 - val_accuracy: 0.2024 - val_loss: 1.6094
# Epoch 66/100
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 66s 120ms/step - accuracy: 0.1992 - loss: 1.6096 - val_accuracy: 0.2024 - val_loss: 1.6094
# Epoch 67/100
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 67s 122ms/step - accuracy: 0.2067 - loss: 1.6093 - val_accuracy: 0.2024 - val_loss: 1.6094
# Epoch 68/100
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 67s 121ms/step - accuracy: 0.2016 - loss: 1.6095 - val_accuracy: 0.2024 - val_loss: 1.6094
# Epoch 69/100
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 67s 121ms/step - accuracy: 0.2067 - loss: 1.6095 - val_accuracy: 0.2012 - val_loss: 1.6094
# Epoch 70/100
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 67s 121ms/step - accuracy: 0.2031 - loss: 1.6093 - val_accuracy: 0.2024 - val_loss: 1.6094
# Epoch 71/100
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 67s 121ms/step - accuracy: 0.2005 - loss: 1.6095 - val_accuracy: 0.2024 - val_loss: 1.6094
# Epoch 72/100
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 67s 122ms/step - accuracy: 0.2065 - loss: 1.6095 - val_accuracy: 0.2024 - val_loss: 1.6094
# Epoch 73/100
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 67s 122ms/step - accuracy: 0.1974 - loss: 1.6096 - val_accuracy: 0.2024 - val_loss: 1.6094
# Epoch 74/100
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 66s 121ms/step - accuracy: 0.2004 - loss: 1.6094 - val_accuracy: 0.2024 - val_loss: 1.6094
# Epoch 75/100
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 67s 122ms/step - accuracy: 0.2031 - loss: 1.6095 - val_accuracy: 0.2024 - val_loss: 1.6094
# Epoch 76/100
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 67s 122ms/step - accuracy: 0.2042 - loss: 1.6096 - val_accuracy: 0.2024 - val_loss: 1.6094
# Epoch 77/100
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 67s 121ms/step - accuracy: 0.2010 - loss: 1.6095 - val_accuracy: 0.2012 - val_loss: 1.6094
# Epoch 78/100
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 66s 120ms/step - accuracy: 0.1975 - loss: 1.6094 - val_accuracy: 0.2024 - val_loss: 1.6094
# Epoch 79/100
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 66s 119ms/step - accuracy: 0.2007 - loss: 1.6095 - val_accuracy: 0.2024 - val_loss: 1.6094
# Epoch 80/100
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 67s 122ms/step - accuracy: 0.2066 - loss: 1.6094 - val_accuracy: 0.2024 - val_loss: 1.6094
# Epoch 81/100
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 68s 124ms/step - accuracy: 0.2015 - loss: 1.6094 - val_accuracy: 0.2024 - val_loss: 1.6094
# Epoch 82/100
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 68s 123ms/step - accuracy: 0.1986 - loss: 1.6095 - val_accuracy: 0.2024 - val_loss: 1.6094
# Epoch 83/100
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 67s 122ms/step - accuracy: 0.2038 - loss: 1.6094 - val_accuracy: 0.2024 - val_loss: 1.6094
# Epoch 84/100
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 66s 121ms/step - accuracy: 0.2005 - loss: 1.6096 - val_accuracy: 0.2024 - val_loss: 1.6094
# Epoch 85/100
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 68s 123ms/step - accuracy: 0.2069 - loss: 1.6095 - val_accuracy: 0.2012 - val_loss: 1.6094
# Epoch 86/100
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 65s 118ms/step - accuracy: 0.1982 - loss: 1.6095 - val_accuracy: 0.2012 - val_loss: 1.6094
# Epoch 87/100
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 66s 120ms/step - accuracy: 0.1967 - loss: 1.6096 - val_accuracy: 0.2012 - val_loss: 1.6094
# Epoch 88/100
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 67s 121ms/step - accuracy: 0.2025 - loss: 1.6094 - val_accuracy: 0.2024 - val_loss: 1.6094
# Epoch 89/100
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 67s 121ms/step - accuracy: 0.2036 - loss: 1.6094 - val_accuracy: 0.2024 - val_loss: 1.6094
# Epoch 90/100
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 66s 119ms/step - accuracy: 0.1996 - loss: 1.6095 - val_accuracy: 0.2024 - val_loss: 1.6094
# Epoch 91/100
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 67s 121ms/step - accuracy: 0.2038 - loss: 1.6095 - val_accuracy: 0.2024 - val_loss: 1.6094
# Epoch 92/100
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 67s 122ms/step - accuracy: 0.2064 - loss: 1.6093 - val_accuracy: 0.2024 - val_loss: 1.6094
# Epoch 93/100
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 66s 120ms/step - accuracy: 0.1975 - loss: 1.6095 - val_accuracy: 0.2024 - val_loss: 1.6094
# Epoch 94/100
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 67s 122ms/step - accuracy: 0.1941 - loss: 1.6095 - val_accuracy: 0.2024 - val_loss: 1.6094
# Epoch 95/100
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 68s 124ms/step - accuracy: 0.2076 - loss: 1.6094 - val_accuracy: 0.2024 - val_loss: 1.6094
# Epoch 96/100
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 68s 123ms/step - accuracy: 0.2016 - loss: 1.6095 - val_accuracy: 0.2024 - val_loss: 1.6094
# Epoch 97/100
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 68s 123ms/step - accuracy: 0.1943 - loss: 1.6098 - val_accuracy: 0.2024 - val_loss: 1.6094
# Epoch 98/100
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 68s 124ms/step - accuracy: 0.2000 - loss: 1.6095 - val_accuracy: 0.2024 - val_loss: 1.6094
# Epoch 99/100
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 67s 122ms/step - accuracy: 0.1975 - loss: 1.6096 - val_accuracy: 0.2024 - val_loss: 1.6094
# Epoch 100/100
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 66s 120ms/step - accuracy: 0.2029 - loss: 1.6095 - val_accuracy: 0.2024 - val_loss: 1.6094
# Epoch 1/50
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 264s 464ms/step - accuracy: 0.2485 - loss: 2.0743 - val_accuracy: 0.1986 - val_loss: 195.4467
# Epoch 2/50
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 256s 465ms/step - accuracy: 0.3804 - loss: 1.5925 - val_accuracy: 0.4122 - val_loss: 1.7839
# Epoch 3/50
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 256s 464ms/step - accuracy: 0.4265 - loss: 1.4337 - val_accuracy: 0.5567 - val_loss: 1.2472
# Epoch 4/50
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 255s 464ms/step - accuracy: 0.4806 - loss: 1.3004 - val_accuracy: 0.5707 - val_loss: 1.2340
# Epoch 5/50
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 254s 461ms/step - accuracy: 0.5040 - loss: 1.2288 - val_accuracy: 0.6029 - val_loss: 1.1554
# Epoch 6/50
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 256s 465ms/step - accuracy: 0.5339 - loss: 1.1660 - val_accuracy: 0.6190 - val_loss: 1.0802
# Epoch 7/50
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 256s 465ms/step - accuracy: 0.5463 - loss: 1.1272 - val_accuracy: 0.6302 - val_loss: 1.0871
# Epoch 8/50
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 264s 481ms/step - accuracy: 0.5757 - loss: 1.0754 - val_accuracy: 0.6576 - val_loss: 0.9993
# Epoch 9/50
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 263s 477ms/step - accuracy: 0.5928 - loss: 1.0199 - val_accuracy: 0.6758 - val_loss: 0.9158
# Epoch 10/50
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 257s 467ms/step - accuracy: 0.6065 - loss: 0.9874 - val_accuracy: 0.6692 - val_loss: 0.8821
# Epoch 11/50
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 256s 464ms/step - accuracy: 0.6227 - loss: 0.9620 - val_accuracy: 0.6923 - val_loss: 0.8473
# Epoch 12/50
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 259s 471ms/step - accuracy: 0.6339 - loss: 0.9268 - val_accuracy: 0.7058 - val_loss: 0.8245
# Epoch 13/50
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 256s 465ms/step - accuracy: 0.6486 - loss: 0.8967 - val_accuracy: 0.7172 - val_loss: 0.7606
# Epoch 14/50
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 257s 468ms/step - accuracy: 0.6539 - loss: 0.8878 - val_accuracy: 0.7116 - val_loss: 0.7975
# Epoch 15/50
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 259s 470ms/step - accuracy: 0.6656 - loss: 0.8560 - val_accuracy: 0.7410 - val_loss: 0.6955
# Epoch 16/50
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 257s 468ms/step - accuracy: 0.6755 - loss: 0.8469 - val_accuracy: 0.7337 - val_loss: 0.6958
# Epoch 17/50
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 257s 467ms/step - accuracy: 0.6947 - loss: 0.8038 - val_accuracy: 0.7446 - val_loss: 0.6716
# Epoch 18/50
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 257s 467ms/step - accuracy: 0.6940 - loss: 0.7916 - val_accuracy: 0.7514 - val_loss: 0.6651
# Epoch 19/50
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 256s 465ms/step - accuracy: 0.6997 - loss: 0.7889 - val_accuracy: 0.7605 - val_loss: 0.6420
# Epoch 20/50
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 259s 470ms/step - accuracy: 0.7077 - loss: 0.7617 - val_accuracy: 0.7745 - val_loss: 0.6050
# Epoch 21/50
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 259s 470ms/step - accuracy: 0.7179 - loss: 0.7421 - val_accuracy: 0.7701 - val_loss: 0.6176
# Epoch 22/50
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 257s 467ms/step - accuracy: 0.7173 - loss: 0.7434 - val_accuracy: 0.7697 - val_loss: 0.6177
# Epoch 23/50
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 255s 464ms/step - accuracy: 0.7268 - loss: 0.7198 - val_accuracy: 0.7753 - val_loss: 0.5957
# Epoch 24/50
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 255s 463ms/step - accuracy: 0.7327 - loss: 0.7056 - val_accuracy: 0.7900 - val_loss: 0.5742
# Epoch 25/50
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 254s 462ms/step - accuracy: 0.7352 - loss: 0.6989 - val_accuracy: 0.7984 - val_loss: 0.5555
# Epoch 26/50
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 256s 465ms/step - accuracy: 0.7412 - loss: 0.6859 - val_accuracy: 0.7968 - val_loss: 0.5521
# Epoch 27/50
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 255s 464ms/step - accuracy: 0.7386 - loss: 0.6799 - val_accuracy: 0.7986 - val_loss: 0.5441
# Epoch 28/50
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 256s 464ms/step - accuracy: 0.7567 - loss: 0.6515 - val_accuracy: 0.7958 - val_loss: 0.5686
# Epoch 29/50
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 256s 465ms/step - accuracy: 0.7574 - loss: 0.6488 - val_accuracy: 0.8085 - val_loss: 0.5289
# Epoch 30/50
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 255s 462ms/step - accuracy: 0.7615 - loss: 0.6398 - val_accuracy: 0.8077 - val_loss: 0.5348
# Epoch 31/50
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 259s 470ms/step - accuracy: 0.7577 - loss: 0.6378 - val_accuracy: 0.8143 - val_loss: 0.5179
# Epoch 32/50
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 257s 467ms/step - accuracy: 0.7647 - loss: 0.6167 - val_accuracy: 0.8197 - val_loss: 0.5079
# Epoch 33/50
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 257s 467ms/step - accuracy: 0.7736 - loss: 0.6014 - val_accuracy: 0.8181 - val_loss: 0.5164
# Epoch 34/50
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 256s 465ms/step - accuracy: 0.7776 - loss: 0.5889 - val_accuracy: 0.8314 - val_loss: 0.4736
# Epoch 35/50
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 254s 462ms/step - accuracy: 0.7827 - loss: 0.5843 - val_accuracy: 0.8181 - val_loss: 0.5161
# Epoch 36/50
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 254s 461ms/step - accuracy: 0.7852 - loss: 0.5758 - val_accuracy: 0.8318 - val_loss: 0.4793
# Epoch 37/50
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 254s 462ms/step - accuracy: 0.7932 - loss: 0.5646 - val_accuracy: 0.8300 - val_loss: 0.4832
# Epoch 38/50
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 253s 460ms/step - accuracy: 0.7890 - loss: 0.5552 - val_accuracy: 0.8396 - val_loss: 0.4563
# Epoch 39/50
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 254s 461ms/step - accuracy: 0.7992 - loss: 0.5381 - val_accuracy: 0.8332 - val_loss: 0.4836
# Epoch 40/50
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 256s 465ms/step - accuracy: 0.7940 - loss: 0.5553 - val_accuracy: 0.8366 - val_loss: 0.4696
# Epoch 41/50
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 258s 469ms/step - accuracy: 0.8026 - loss: 0.5249 - val_accuracy: 0.8418 - val_loss: 0.4484
# Epoch 42/50
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 255s 463ms/step - accuracy: 0.8083 - loss: 0.5209 - val_accuracy: 0.8493 - val_loss: 0.4271
# Epoch 43/50
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 254s 461ms/step - accuracy: 0.8046 - loss: 0.5309 - val_accuracy: 0.8497 - val_loss: 0.4418
# Epoch 44/50
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 254s 461ms/step - accuracy: 0.8086 - loss: 0.5049 - val_accuracy: 0.8388 - val_loss: 0.4753
# Epoch 45/50
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 254s 462ms/step - accuracy: 0.8130 - loss: 0.5089 - val_accuracy: 0.8392 - val_loss: 0.4630
# Epoch 46/50
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 255s 464ms/step - accuracy: 0.8154 - loss: 0.5023 - val_accuracy: 0.8493 - val_loss: 0.4258
# Epoch 47/50
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 255s 464ms/step - accuracy: 0.8176 - loss: 0.4902 - val_accuracy: 0.8487 - val_loss: 0.4315
# Epoch 48/50
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 256s 465ms/step - accuracy: 0.8163 - loss: 0.4946 - val_accuracy: 0.8505 - val_loss: 0.4299
# Epoch 49/50
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 255s 463ms/step - accuracy: 0.8283 - loss: 0.4759 - val_accuracy: 0.8607 - val_loss: 0.4019
# Epoch 50/50
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 255s 464ms/step - accuracy: 0.8224 - loss: 0.4744 - val_accuracy: 0.8533 - val_loss: 0.4257

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, classification_report

# Path to the test set directory
test_data_dir = '/Users/randithasenarathne/FYP/FabricDefects/cls-multi/test'

# Use ImageDataGenerator without any augmentation for the test set
test_datagen = ImageDataGenerator(rescale=1.0/255.0)

# Create a test generator
test_generator = test_datagen.flow_from_directory(
    test_data_dir,
    target_size=(64, 64),  # Ensure the same image size used for training
    batch_size=32,
    class_mode='categorical',
    shuffle=False  # No shuffling, we want to keep the order for evaluation
)

# Get the true labels from the test generator
y_true_test = test_generator.classes

# Predict the classes for the test set
y_pred_test = model.predict(test_generator)
y_pred_test_classes = y_pred_test.argmax(axis=1)  # Get predicted class indices

# Calculate accuracy, precision, recall, and F1 score
accuracy_test = accuracy_score(y_true_test, y_pred_test_classes)
precision_test = precision_score(y_true_test, y_pred_test_classes, average='macro')
recall_test = recall_score(y_true_test, y_pred_test_classes, average='macro')
f1_test = f1_score(y_true_test, y_pred_test_classes, average='macro')

# Print the results for the test set
print(f"Test Accuracy: {accuracy_test}")
print(f"Test Precision: {precision_test}")
print(f"Test Recall: {recall_test}")
print(f"Test F1 Score: {f1_test}")

# Print the classification report for the test set
print(classification_report(y_true_test, y_pred_test_classes, target_names=test_generator.class_indices.keys()))
# Out:
# Found 2515 images belonging to 5 classes.
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 7s 88ms/step
# Test Accuracy: 0.8600397614314115
# Test Precision: 0.8697305911451997
# Test Recall: 0.8596918473563347
# Test F1 Score: 0.8602479731936201
#                        precision    recall  f1-score   support
#
#          foreign yarn       0.86      0.78      0.82       503
#                  good       0.73      0.93      0.82       500
#                  hole       0.92      0.91      0.91       506
#                  slub       0.94      0.77      0.85       496
# surface contamination       0.89      0.91      0.90       510
#
#              accuracy                           0.86      2515
#             macro avg       0.87      0.86      0.86      2515
#          weighted avg       0.87      0.86      0.86      2515

# %%
model.save('/Users/randithasenarathne/FYP/runs/classify/Resnet.keras')

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Load your trained VGG model
model_path = '/Users/randithasenarathne/FYP/runs/classify/Resnet.keras'
model = load_model(model_path)

# Set up your test data generator
test_dir = '/Users/randithasenarathne/FYP/FabricDefects/cls-multi/test'
batch_size = 32
img_size = (64, 64)  # Change to your model's input size

test_datagen = ImageDataGenerator(rescale=1./255)
test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=img_size,
    batch_size=batch_size,
    class_mode='categorical',
    shuffle=False
)

# Make predictions on the test data
Y_pred = model.predict(test_generator)
y_pred = np.argmax(Y_pred, axis=1)

# Get the true labels
y_true = test_generator.classes

# Define the class labels
class_labels = list(test_generator.class_indices.keys())

# Compute the confusion matrix
cm = confusion_matrix(y_true, y_pred)
cm_normalized = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

# Plot the confusion matrix
plt.figure(figsize=(8, 6))
disp = ConfusionMatrixDisplay(confusion_matrix=cm_normalized, display_labels=class_labels)
disp.plot(cmap=plt.cm.Blues)
plt.title('Normalized Confusion Matrix(ResNet50)')
plt.show()
# Out:
# Found 2515 images belonging to 5 classes.
# /Applications/anaconda3/lib/python3.11/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 8s 91ms/step

# %%
import cv2
import numpy as np
from keras.models import load_model
from PIL import Image
from collections import deque
import ipywidgets as widgets
from IPython.display import display

# Load the ResNet model (update the path to your trained ResNet model)
model_path = '/Users/randithasenarathne/FYP/runs/classify/Resnet.keras'
model = load_model(model_path)

def preprocess_image(frame):
    # Convert the frame to RGB (ResNet expects 3-channel input)
    rgb_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
    
    # Resize the frame to 224x224 (the typical input size for ResNet)
    resized_frame = cv2.resize(rgb_frame, (64, 64))
    
    # Normalize the frame (ResNet models usually expect pixel values in range [0, 1])
    normalized_frame = resized_frame.astype(np.float32) / 255.0
    
    # Add batch dimension (required by the model)
    batch_frame = np.expand_dims(normalized_frame, axis=0)
    
    return batch_frame

def predict(frame, model):
    # Preprocess the frame
    image = preprocess_image(frame)
    
    # Make prediction
    predictions = model.predict(image)
    
    return predictions

def post_process_results(predictions):
    # Extract the predicted class probabilities
    predicted_class = np.argmax(predictions[0])
    
    return predicted_class

# Define class names
class_names = ['foreign yarn', 'good', 'hole', 'slub', 'surface contamination']

# Initialize widgets for length and width
length_widget = widgets.FloatText(description="Length (m):")
width_widget = widgets.FloatText(description="Width (m):")
display(length_widget, width_widget)

# Variables to handle pausing and fault rate calculation
is_paused = False
fault_points = 0
frame_count = 0
recent_defects = deque(maxlen=3)
defects_within_meter = deque(maxlen=30)  # Assuming 30 frames per meter for this example

def calculate_fault_rate(fault_points, roll_length, roll_width):
    return (fault_points * 0.84 * 100) / (roll_length * roll_width)

def process_frame(frame, is_paused, fault_points, recent_defects, defects_within_meter, frame_count):
    if not is_paused:
        # Predict the class for the current frame using ResNet
        predictions = predict(frame, model)
        predicted_class = post_process_results(predictions)
        
        # Update fault points based on predictions
        if class_names[predicted_class] in ['slub', 'foreign yarn', 'surface contamination']:
            fault_points += 1
        elif class_names[predicted_class] == 'hole':
            fault_points += 4
        
        # Track recent defects to identify clusters of defects
        if class_names[predicted_class] != 'good':
            recent_defects.append((class_names[predicted_class], frame_count))
            defects_within_meter.append((class_names[predicted_class], frame_count))
        
        # Check for long defects or clusters of defects
        if len(recent_defects) >= 3:
            if len(set(d[0] for d in recent_defects)) > 1 or (recent_defects[-1][1] - recent_defects[0][1]) < 30:
                fault_points += 4
                recent_defects.clear()
        
        # Check for more than 3 fabric defects within one meter
        if len(defects_within_meter) >= 3:
            if defects_within_meter[-1][1] - defects_within_meter[0][1] < 30:
                fault_points += 4
                defects_within_meter.clear()
        
        # Display the prediction on the frame
        cv2.putText(frame, f'Predicted Class: {class_names[predicted_class]}', (10, 30),
                    cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2, cv2.LINE_AA)
    
    # Show the frame
    cv2.imshow('Fabric Defect Detection', frame)
    
    frame_count += 1
    return fault_points, recent_defects, defects_within_meter, frame_count

def run_detection():
    # Get the roll length and width from widgets
    roll_length = length_widget.value
    roll_width = width_widget.value
    
    if roll_length == 0 or roll_width == 0:
        print("Please enter valid roll length and width.")
        return
    
    # Start video capture
    cap = cv2.VideoCapture(0)  # Use 0 for the default camera or replace with video file path
    
    global is_paused, fault_points, frame_count, recent_defects, defects_within_meter
    
    while True:
        ret, frame = cap.read()
        if not ret:
            break
        
        fault_points, recent_defects, defects_within_meter, frame_count = process_frame(
            frame, is_paused, fault_points, recent_defects, defects_within_meter, frame_count)
        
        key = cv2.waitKey(1)
        if key & 0xFF == ord('q'):
            break
        elif key & 0xFF == ord('p'):
            is_paused = not is_paused
    
    # Calculate and print fault rate
    fault_rate = calculate_fault_rate(fault_points, roll_length, roll_width)
    print(f"Fault Rate: {fault_rate:.2f}%")
    
    # Release video capture and close windows
    cap.release()
    cv2.destroyAllWindows()

# Run the detection
run_detection()
# Out:
# FloatText(value=0.0, description='Length (m):')
# FloatText(value=0.0, description='Width (m):')
# Please enter valid roll length and width.

# %%
run_detection()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 507ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Fault Rate: 1176.56%

# %%
import cv2
import numpy as np
from keras.models import load_model
from collections import deque
import ipywidgets as widgets
from IPython.display import display

# Load the ResNet model (update the path to your trained ResNet model)
model_path = '/Users/randithasenarathne/FYP/runs/classify/Resnet.keras'
model = load_model(model_path)

# Preprocess the image frame before feeding it to the model
def preprocess_image(frame):
    # Convert the frame to RGB (ResNet expects 3-channel input)
    rgb_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
    
    # Resize the frame to 64x64 (the input size you are using)
    resized_frame = cv2.resize(rgb_frame, (64, 64))
    
    # Normalize the frame (ResNet models usually expect pixel values in range [0, 1])
    normalized_frame = resized_frame.astype(np.float32) / 255.0
    
    # Add batch dimension (required by the model)
    batch_frame = np.expand_dims(normalized_frame, axis=0)
    
    return batch_frame

# Predict the class of the fabric defect using the model
def predict(frame, model):
    # Preprocess the frame
    image = preprocess_image(frame)
    
    # Make prediction
    predictions = model.predict(image)
    
    return predictions

# Post-process the results to get the predicted class
def post_process_results(predictions):
    # Extract the predicted class probabilities
    predicted_class = np.argmax(predictions[0])
    
    return predicted_class

# Define class names for the fabric defects (update this based on your ResNet model)
class_names = ['foreign yarn', 'good', 'hole', 'slub', 'surface contamination']

# Initialize widgets for length and width
length_widget = widgets.FloatText(description="Length (m):")
width_widget = widgets.FloatText(description="Width (m):")
display(length_widget, width_widget)

# Variables to handle pausing, fault rate calculation, and defect tracking
is_paused = False
fault_points = 0
frame_count = 0
recent_defects = deque(maxlen=3)
defects_within_meter = deque(maxlen=30)  # Assuming 30 frames per meter for this example

# Add variables to track last detected defect and its frame
last_defect = None
last_defect_frame = -10  # Start with a negative frame number to prevent any issues

# Calculate the fault rate based on roll length and width
def calculate_fault_rate(fault_points, roll_length, roll_width):
    return (fault_points * 0.84 * 100) / (roll_length * roll_width)

# Process each frame, applying the cooldown mechanism and updating fault points
def process_frame(frame, is_paused, fault_points, recent_defects, defects_within_meter, frame_count, last_defect, last_defect_frame):
    if not is_paused:
        # Predict the class for the current frame using the model
        predictions = predict(frame, model)
        predicted_class = post_process_results(predictions)
        
        # Check if the current defect is the same as the last detected one and if it's within a "cooldown" period
        if class_names[predicted_class] != 'good':  # Only consider defective frames
            if class_names[predicted_class] != last_defect or (frame_count - last_defect_frame) > 10:
                # Update fault points based on the predicted class
                if class_names[predicted_class] in ['slub', 'foreign yarn', 'surface contamination']:
                    fault_points += 1
                elif class_names[predicted_class] == 'hole':
                    fault_points += 4

                # Update last defect tracking variables
                last_defect = class_names[predicted_class]
                last_defect_frame = frame_count

                # Track recent defects for clustering purposes
                recent_defects.append((class_names[predicted_class], frame_count))
                defects_within_meter.append((class_names[predicted_class], frame_count))
            
        # Check for long defects or clusters of defects
        if len(recent_defects) >= 3:
            if len(set(d[0] for d in recent_defects)) > 1 or (recent_defects[-1][1] - recent_defects[0][1]) < 30:
                fault_points += 4
                recent_defects.clear()
        
        # Check for more than 3 fabric defects within one meter
        if len(defects_within_meter) >= 3:
            if defects_within_meter[-1][1] - defects_within_meter[0][1] < 30:
                fault_points += 4
                defects_within_meter.clear()
        
        # Display the prediction on the frame
        cv2.putText(frame, f'Predicted Class: {class_names[predicted_class]}', (10, 30),
                    cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2, cv2.LINE_AA)
    
    # Show the frame
    cv2.imshow('Fabric Defect Detection', frame)
    
    frame_count += 1
    return fault_points, recent_defects, defects_within_meter, frame_count, last_defect, last_defect_frame

# Main function to run the fabric defect detection
def run_detection():
    # Get the roll length and width from widgets
    roll_length = length_widget.value
    roll_width = width_widget.value
    
    if roll_length == 0 or roll_width == 0:
        print("Please enter valid roll length and width.")
        return
    
    # Start video capture
    cap = cv2.VideoCapture(0)  # Use 0 for the default camera or replace with video file path
    
    global is_paused, fault_points, frame_count, recent_defects, defects_within_meter
    global last_defect, last_defect_frame
    
    while True:
        ret, frame = cap.read()
        if not ret:
            break
        
        fault_points, recent_defects, defects_within_meter, frame_count, last_defect, last_defect_frame = process_frame(
            frame, is_paused, fault_points, recent_defects, defects_within_meter, frame_count, last_defect, last_defect_frame
        )
        
        # Handle user input
        key = cv2.waitKey(1) & 0xFF
        if key == ord('q'):
            break
        elif key == ord('p'):
            is_paused = not is_paused
            if is_paused:
                fault_rate = calculate_fault_rate(fault_points, roll_length, roll_width)
                print(f"Fault Rate: {fault_rate}%")
                # Reset fault_points and frame_count for next roll length
                fault_points, frame_count = 0, 0
    
    cap.release()
    cv2.destroyAllWindows()

# Run the fabric defect detection
run_detection()
# Out:
# FloatText(value=0.0, description='Length (m):')
# FloatText(value=0.0, description='Width (m):')
# Please enter valid roll length and width.

# %%
# Run the fabric defect detection
run_detection()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 574ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Fault Rate: 21.0%

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Given metrics for the models
metrics = {
    "Model": ["YOLO", "VGG", "ResNet"],
    "Accuracy": [0.8954, 0.8831, 0.86],
    "Precision": [0.9024, 0.8908, 0.8697],
    "Recall": [0.8953, 0.8832, 0.8597],
    "F1 Score": [0.8989, 0.8841, 0.8602]
}

# Convert to DataFrame
metrics_df = pd.DataFrame(metrics)

# Create a heatmap for the given metrics with adjusted color range
plt.figure(figsize=(8, 5))
sns.heatmap(metrics_df.set_index('Model').T, annot=True, cmap="Blues", cbar=True, linewidths=0.5, fmt='.4f', vmin=0.85, vmax=0.91)

plt.title("Model Performance Metrics (YOLO, VGG, ResNet)")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Load your trained VGG model
model_path = '/Users/randithasenarathne/FYP/runs/classify/Resnet.keras'
model = load_model(model_path)

# Set up your test data generator
test_dir = '/Users/randithasenarathne/FYP/FabricDefects/cls-multi/test'
batch_size = 32
img_size = (64, 64)  # Change to your model's input size

test_datagen = ImageDataGenerator(rescale=1./255)
test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=img_size,
    batch_size=batch_size,
    class_mode='categorical',
    shuffle=False
)

# Make predictions on the test data
Y_pred = model.predict(test_generator)
y_pred = np.argmax(Y_pred, axis=1)

# Get the true labels
y_true = test_generator.classes

# Define the class labels
class_labels = list(test_generator.class_indices.keys())

# Compute the confusion matrix
cm = confusion_matrix(y_true, y_pred)
cm_normalized = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

# Plot the confusion matrix
plt.figure(figsize=(8, 6))
disp = ConfusionMatrixDisplay(confusion_matrix=cm_normalized, display_labels=class_labels)
disp.plot(cmap=plt.cm.Blues)

# Rotate x-axis labels by 45 degrees
plt.xticks(rotation=45)

plt.title('Normalized Confusion Matrix (ResNet50)')
plt.show()
# Out:
# Found 2515 images belonging to 5 classes.
# /Applications/anaconda3/lib/python3.11/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 8s 92ms/step
